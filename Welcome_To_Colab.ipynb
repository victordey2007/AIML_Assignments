# %% [markdown]
# <a href="https://colab.research.google.com/github/victordey2007/AIML_Assignments/blob/assignment_python/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %%
test=['a','b','c','d']
test3=['a',test,1,1.2]
test1=['c','b']
print(test[0:2])
test[0:2]='aa','ab'
print(test[0:2])
test.append('tt')
test.insert(2,'ff')

print(test3[1])

cars_type=["sedan","Hatchback","SUV","MUV"]
mlilage=[12,23,34,45]

print(cars_type.index('SUV'))
# Out:
# ['a', 'b']
# ['aa', 'ab']
# ['aa', 'ab', 'ff', 'c', 'd', 'tt']
# 2

# %% [markdown]
# # how to use list and index

# %%
cars_type=["sedan","Hatchback","SUV","MUV"]
mlilage=[12,23,34,45]

print(cars_type.index('SUV'))
